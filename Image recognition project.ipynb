# %%
import os
import warnings
warnings.simplefilter("ignore")

# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from skimage.io import imread,imshow
from skimage.transform import resize
from skimage.color import rgb2gray

# %%
messi=os.listdir("D:/images/leo messi")

# %%
sadie=os.listdir("D:/images/sadie sink")

# %%
niall=os.listdir("D:/images/niall horan")

# %%
limit=50
messi_images=[None]*limit
j=0
for i in messi:
    if(j<limit):
        messi_images[j]=imread("D:/images/leo messi/"+i)
        j+=1
    else:
        break

# %%
imshow(messi_images[3])

# %%
limit=50
sadie_images=[None]*limit
j=0
for i in sadie:
    if(j<limit):
        sadie_images[j]=imread("D:/images/sadie sink/"+i)
        j+=1
    else:
        break

# %%
imshow(sadie_images[3])

# %%
limit=50
niall_images=[None]*limit
j=0
for i in niall:
    if(j<limit):
        niall_images[j]=imread("D:/images/niall horan/"+i)
        j+=1
    else:
        break

# %%
imshow(niall_images[3])

# %%
messi_gray=[None]*limit
j=0
for i in messi:
    if(j<limit):
        messi_gray[j]=rgb2gray(messi_images[j])
        j+=1
    else:
        break

# %%
sadie_gray=[None]*limit
j=0
for i in sadie:
    if(j<limit):
        sadie_gray[j]=rgb2gray(sadie_images[j])
        j+=1
    else:
        break

# %%
niall_gray=[None]*limit
j=0
for i in niall:
    if(j<limit):
        niall_gray[j]=rgb2gray(niall_images[j])
        j+=1
    else:
        break

# %%
imshow(messi_gray[3])

# %%
imshow(sadie_gray[3])

# %%
imshow(niall_gray[3])

# %%
messi_gray[3].shape
# Out:
# (1175, 1920)

# %%
sadie_gray[1].shape
# Out:
# (1927, 1280)

# %%
niall_gray[7].shape
# Out:
# (1024, 639)

# %%
for j in range(50):
  sp=messi_gray[j]
  messi_gray[j]=resize(sp,(512,512))

# %%
for j in range(50):
  ss=sadie_gray[j]
  sadie_gray[j]=resize(ss,(512,512))

# %%
for j in range(50):
  dc=niall_gray[j]
  niall_gray[j]=resize(dc,(512,512))

# %%
imshow(messi_gray[4])

# %%
imshow(sadie_gray[4])

# %%
imshow(niall_gray[4])

# %%
len_of_images_messi=len(messi_gray)
len_of_images_messi
# Out:
# 50

# %%
len_of_images_sadie=len(sadie_gray)
len_of_images_sadie
# Out:
# 50

# %%
len_of_images_niall=len(niall_gray)
len_of_images_niall
# Out:
# 50

# %%
image_size_messi=messi_gray[1].shape
image_size_messi
# Out:
# (512, 512)

# %%
image_size_sadie=sadie_gray[1].shape
image_size_sadie
# Out:
# (512, 512)

# %%
image_size_niall=niall_gray[1].shape
image_size_niall
# Out:
# (512, 512)

# %%
flatten_size_messi=image_size_messi[0]*image_size_messi[1]
flatten_size_messi
# Out:
# 262144

# %%
flatten_size_sadie=image_size_sadie[0]*image_size_sadie[1]
flatten_size_sadie
# Out:
# 262144

# %%
flatten_size_niall=image_size_niall[0]*image_size_niall[1]
flatten_size_niall
# Out:
# 262144

# %%
for i in range(len_of_images_messi):
  messi_gray[i]=np.ndarray.flatten(messi_gray[i]).reshape(flatten_size_messi,1)

# %%
for i in range(len_of_images_sadie):
  sadie_gray[i]=np.ndarray.flatten(sadie_gray[i]).reshape(flatten_size_sadie,1)

# %%
for i in range(len_of_images_niall):
  niall_gray[i]=np.ndarray.flatten(niall_gray[i]).reshape(flatten_size_niall,1)

# %%
messi_gray=np.dstack(messi_gray)
messi_gray.shape
# Out:
# (262144, 1, 50)

# %%
sadie_gray=np.dstack(sadie_gray)
sadie_gray.shape
# Out:
# (262144, 1, 50)

# %%
niall_gray=np.dstack(niall_gray)
niall_gray.shape
# Out:
# (262144, 1, 50)

# %%
messi_gray=np.rollaxis(messi_gray,axis=2,start=0)
messi_gray.shape
# Out:
# (50, 262144, 1)

# %%
sadie_gray=np.rollaxis(sadie_gray,axis=2,start=0)
sadie_gray.shape
# Out:
# (50, 262144, 1)

# %%
niall_gray=np.rollaxis(niall_gray,axis=2,start=0)
niall_gray.shape
# Out:
# (50, 262144, 1)

# %%
messi_gray=messi_gray.reshape(len_of_images_messi,flatten_size_messi)
messi_gray.shape
# Out:
# (50, 262144)

# %%
sadie_gray=sadie_gray.reshape(len_of_images_sadie,flatten_size_sadie)
sadie_gray.shape
# Out:
# (50, 262144)

# %%
niall_gray=niall_gray.reshape(len_of_images_niall,flatten_size_niall)
niall_gray.shape
# Out:
# (50, 262144)

# %%
messi_data=pd.DataFrame(messi_gray)
messi_gray
# Out:
# array([[0.74970242, 0.75680659, 0.76289527, ..., 1.        , 1.        ,
#         1.        ],
#        [0.01568627, 0.01568627, 0.01568627, ..., 0.11821203, 0.11625176,
#         0.1142915 ],
#        [0.01132777, 0.01133488, 0.0121195 , ..., 0.03013354, 0.0372721 ,
#         0.03749308],
#        ...,
#        [0.21702629, 0.22535385, 0.22289514, ..., 0.52182251, 0.58610784,
#         0.53284924],
#        [0.29946634, 0.28830953, 0.28145697, ..., 0.21203259, 0.21203255,
#         0.21203255],
#        [0.10195844, 0.10195855, 0.10195063, ..., 0.24431601, 0.2443267 ,
#         0.24460026]])

# %%
sadie_data=pd.DataFrame(sadie_gray)
sadie_gray
# Out:
# array([[0.3842244 , 0.38772592, 0.38772592, ..., 0.22457584, 0.22457584,
#         0.22457584],
#        [0.07850927, 0.07131312, 0.06926211, ..., 0.62912776, 0.73927518,
#         0.74907438],
#        [0.40606267, 0.40092685, 0.39126736, ..., 0.73780969, 0.73628837,
#         0.73439835],
#        ...,
#        [0.72538226, 0.72984656, 0.65763487, ..., 0.77777904, 0.77777904,
#         0.77777904],
#        [0.42507235, 0.42507235, 0.42506319, ..., 0.06464396, 0.0655664 ,
#         0.07330529],
#        [0.37752852, 0.37968774, 0.38300661, ..., 0.74869576, 0.75171477,
#         0.75311039]])

# %%
# ..        ...       ...       ...       ...       ...       ...       ...
# 145  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 146  0.022714  0.020033  0.027434  0.019828  0.022756  0.023338  0.023909
# 147  0.181844  0.181844  0.181854  0.184277  0.185765  0.185765  0.185765
# 148  0.468281  0.468439  0.471251  0.474224  0.469319  0.473590  0.475550
# 149  0.086417  0.089167  0.091220  0.095543  0.112553  0.128725  0.137430
#
#             7         8         9  ...    262135    262136    262137  \
# ...

# %%
x=hollywood_actors.values[:,:-1]

# %%
y=hollywood_actors.values[:,-1]

# %%
x
# Out:
# array([[0.18162455627321047, 0.18046568852961692, 0.1755238565232114,
#         ..., 0.5711487425936843, 0.5466806436717313, 0.5318515232834394],
#        [0.6214514908893938, 0.6173573220827392, 0.616298364009525, ...,
#         0.5469822499958154, 0.5501232512986118, 0.5486051944968584],
#        [0.9363899520381722, 0.9173604274569463, 0.9049338427386727, ...,
#         0.36020645948273267, 0.3867626702201531, 0.3420469892577356],
#        ...,
#        [0.1818435294117647, 0.18184352941176468, 0.18185360098310444,
#         ..., 0.6274699381949269, 0.6303013568289124, 0.6229376314317188],
#        [0.4682814732266649, 0.4684388533621064, 0.47125125393550527, ...,
#         0.05713842133553856, 0.06409063093624862, 0.07780492710181428],
#        [0.08641727676627806, 0.08916674658481151, 0.09121988489403053,
#         ..., 0.8888853832662051, 0.8872756697079669, 0.8922206971393384]],
#       dtype=object)

# %%
y
# Out:
# array(['sadie sink', 'leo messi', 'sadie sink', 'sadie sink', 'leo messi',
#        'leo messi', 'niall horan', 'leo messi', 'sadie sink', 'leo messi',
#        'sadie sink', 'leo messi', 'niall horan', 'leo messi',
#        'sadie sink', 'leo messi', 'niall horan', 'leo messi',
#        'sadie sink', 'sadie sink', 'sadie sink', 'leo messi',
#        'niall horan', 'sadie sink', 'leo messi', 'sadie sink',
#        'leo messi', 'niall horan', 'niall horan', 'leo messi',
#        'leo messi', 'leo messi', 'leo messi', 'leo messi', 'niall horan',
#        'leo messi', 'niall horan', 'leo messi', 'leo messi', 'sadie sink',
#        'leo messi', 'niall horan', 'sadie sink', 'leo messi', 'leo messi',
#        'sadie sink', 'niall horan', 'sadie sink', 'sadie sink',
#        'sadie sink', 'leo messi', 'leo messi', 'niall horan',
#        'niall horan', 'niall horan', 'sadie sink', 'sadie sink',
#        'sadie sink', 'niall horan', 'niall horan', 'sadie sink',
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
from sklearn import svm

# %%
clf=svm.SVC()
clf.fit(x_train,y_train)
# Out:
# SVC()

# %%
y_pred=clf.predict(x_test)

# %%
y_pred
# Out:
# array(['sadie sink', 'leo messi', 'leo messi', 'sadie sink', 'leo messi',
#        'niall horan', 'leo messi', 'niall horan', 'leo messi',
#        'niall horan', 'niall horan', 'leo messi', 'niall horan',
#        'niall horan', 'sadie sink', 'leo messi', 'leo messi',
#        'sadie sink', 'niall horan', 'niall horan', 'leo messi',
#        'leo messi', 'leo messi', 'niall horan', 'leo messi',
#        'niall horan', 'leo messi', 'niall horan', 'niall horan',
#        'leo messi'], dtype=object)

# %%
for i in (np.random.randint(0,30,10)):
  predicted_images=(np.reshape(x_test[i],(512,512)).astype(np.float64))
  plt.title("Predicted label: {0}".format(y_pred[i]))
  plt.imshow(predicted_images,interpolation="nearest",cmap="gray")
  plt.show()

# %%
from sklearn import metrics

# %%
accuracy=metrics.accuracy_score(y_test,y_pred)

# %%
accuracy
# Out:
# 0.8666666666666667

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[14,  0,  0],
#        [ 0,  8,  0],
#        [ 0,  4,  4]], dtype=int64)
